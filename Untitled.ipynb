# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pymongo
import joblib
import os

# Set visual style
sns.set_theme(style="whitegrid")
# %matplotlib inline 
client = pymongo.MongoClient("mongodb+srv://admin:1234@cluster0.vbcsfq7.mongodb.net/?appName=Cluster0")
db = client["GlobalCurb"]
logs_col = db["live_training_logs"]
MODEL_PATH = 'adaptive_brain.pkl'

print("Connection Successful!")
# Out:
# Connection Successful!

# %%
# Fetch logs from MongoDB
logs = list(logs_col.find())

if logs:
    df = pd.DataFrame(logs)
    print(f"Total records retrieved: {len(df)}")
    display(df.head()) # Shows the first 5 rows in a nice table
else:
    print("No data found in MongoDB. Go interact with your app first!")
# Out:
# Total records retrieved: 26
#                         _id        lat        lon  hour  quality  price  \
# 0  69ea9265c015c252ff6853b3  18.639873  73.789478    21        0   52.0
# 1  69ea94b9c015c252ff6853e5  18.639612  73.789566    21        1   72.0
# 2  69ea94d9c015c252ff6853ea  18.639612  73.789566    21        1   72.0
# 3  69ea960cc015c252ff685407  18.640051  73.789558    21        0   52.0
# 4  69ea9616c015c252ff68540a  18.640051  73.789558    21        0   52.0
#
#     outcome
# 0  Accepted
# 1  Declined
# 2  Accepted
# 3  Declined
# 4  Declined

# %%
#question:What is the most common price range users are seeing?
plt.figure(figsize=(10, 5))
sns.histplot(df['price'], kde=True, color='black', bins=15)
plt.title("Frequency of Market Prices", fontsize=15)
plt.xlabel("Price (₹)")
plt.ylabel("Number of Observations")
plt.show()

# %%
#question: Are users happy with the AI-generated prices?
plt.figure(figsize=(5, 5))
# Using your 'outcome' column from logs_col.insert_one
sns.countplot(data=df, x='outcome', palette=['#2ecc71', '#e74c3c'])
plt.title("Driver Feedback Sentiment", fontsize=15)
plt.show()
# Out:
# C:\Users\Ritika\AppData\Local\Temp\ipykernel_33248\1513745468.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='outcome', palette=['#2ecc71', '#e74c3c'])

# %%
# Out:
# The .pkl file is missing. Run your Streamlit app and trigger a retrain first!
